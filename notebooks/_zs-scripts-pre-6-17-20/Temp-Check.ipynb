# %% [markdown]
# ## Temperature Observational Data vs CESM-LE
# Notebook objectives:
#
# 1) Get the model grid and generate region mask
#
# 2) open global POP-regridded OISST 1991-2019 data
#
# 3) Compute regional means
#
# 4) Plot it!

# %%
from itertools import product

import numpy as np
import xarray as xr

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import pop_tools
import xpersist as xp

import util

# %%
clobber = False

# %% [markdown]
# ### 1) Get the model grid and generate region mask
# Where we are using the pop_tools package. This reads the same binary files that the model read to generate the grid online.

# %%
grid = pop_tools.get_grid('POP_gx1v6')
grid
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# /glade/work/zephyrs/miniconda3/envs/krill-2/lib/python3.7/site-packages/pooch/utils.py in make_local_storage(path, env)
#     278             action = "write to"
# --> 279             with tempfile.NamedTemporaryFile(dir=path):
#     280                 pass
#
# /glade/work/zephyrs/miniconda3/envs/krill-2/lib/python3.7/tempfile.py in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete)
#     546
# --> 547     (fd, name) = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     548     try:
#
# /glade/work/zephyrs/miniconda3/envs/krill-2/lib/python3.7/tempfile.py in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     257         try:
# --> 258             fd = _os.open(file, flags, 0o600)
#     259         except FileExistsError:
#
# ...

# %% [markdown]
# ### 2) open global POP-regridded OISST 1991-2019 data

# %%
dsobs = xr.open_zarr('/glade/p/cgd/oce/projects/krill-cesm-le/data/oisst-avhrr-v02r01.1991-2019_DJF.POP_gx1v6.zarr')
dsobs
# Out:
# <xarray.Dataset>
# Dimensions:  (nlat: 384, nlon: 320, time: 28)
# Coordinates:
#     TLAT     (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     TLONG    (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#   * time     (time) int64 1992 1993 1994 1995 1996 ... 2015 2016 2017 2018 2019
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     KMT      (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     TAREA    (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     anom     (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     err      (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     ice      (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>
#     sst      (time, nlat, nlon) float64 dask.array<chunksize=(1, 384, 320), meta=np.ndarray>

# %% [markdown]
# ### 3) Compute regional means

# %% [markdown]
# ### 4) Plot it!
