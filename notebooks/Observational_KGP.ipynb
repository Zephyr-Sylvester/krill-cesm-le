# %%
import xarray as xr
import numpy as np
import util

# %%
#ds_obs = xr.open_zarr('/glade/p/cgd/oce/projects/krill-cesm-le/data/oisst-avhrr-v02r01.1990-2019_DJF.POP_gx1v6.zarr')
dss = xr.open_zarr('/glade/p/cgd/oce/projects/krill-cesm-le/data/oisst-avhrr-v02r01.1982-2019_DJF.POP_gx1v6.zarr')
#rename
dss['SST'] = dss['sst']
#select specific variables to include in sliced dataset
grid_vars = ['KMT', 'TAREA', 'TLAT', 'TLONG', 'time']
data_vars = ['SST']

dss = dss[data_vars+grid_vars].isel(nlat=slice(0, 93) , time=slice(15,28) )
dss
# Out:
# <xarray.Dataset>
# Dimensions:  (nlat: 93, nlon: 320, time: 13)
# Coordinates:
#     TLAT     (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     TLONG    (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#   * time     (time) int64 1998 1999 2000 2001 2002 ... 2006 2007 2008 2009 2010
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     SST      (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     KMT      (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     TAREA    (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>

# %%
dsc = xr.open_zarr(f'{util.project_tmpdir}/seawifs_mapped_monthly_chl_gsm_DJF.POP_gx1v6.zarr')
#rename
dsc['Chl_surf'] = dsc['chl_gsm']
#select specific variables to include in sliced dataset
grid_vars = ['KMT', 'TAREA', 'TLAT', 'TLONG', 'time']
data_vars = ['Chl_surf']

dsc = dsc[data_vars+grid_vars].isel(nlat=slice(0, 93))
dsc
# Out:
# <xarray.Dataset>
# Dimensions:   (nlat: 93, nlon: 320, time: 12)
# Coordinates:
#     TLAT      (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     TLONG     (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#   * time      (time) int64 1998 1999 2000 2001 2002 ... 2005 2006 2007 2009 2010
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     Chl_surf  (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     KMT       (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>
#     TAREA     (time, nlat, nlon) float64 dask.array<chunksize=(1, 93, 320), meta=np.ndarray>

# %%
length = xr.DataArray(
    [20., 40., 60.], 
    name='length',
    dims=('length'), 
    attrs={'units': 'mm', 'long_name': 'Krill body length'})
length
# Out:
# <xarray.DataArray 'length' (length: 3)>
# array([20., 40., 60.])
# Dimensions without coordinates: length
# Attributes:
#     units:      mm
#     long_name:  Krill body length

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-4a82d50cf50f> in <module>
# ----> 1 ds = compute_kgp(dsc.Chl_surf, dss.SST, length)
#       2 ds
#
# <ipython-input-39-57b1822dd356> in compute_kgp(c, t, length)
#      35     # add coordinates
#      36     kgp = kgp.assign_coords({'length': length})
# ---> 37     kgp = kgp.assign_coords({'TLONG': c.TLONG, 'TLAT': c.TLAT})
#      38
#      39     # add attrs
#
# AttributeError: 'float' object has no attribute 'TLONG'
