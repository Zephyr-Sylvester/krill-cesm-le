# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Finding-forced-trends-in-oceanic-oxygen" data-toc-modified-id="Finding-forced-trends-in-oceanic-oxygen-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Finding forced trends in oceanic oxygen</a></span><ul class="toc-item"><li><span><a href="#Learning-Objectives" data-toc-modified-id="Learning-Objectives-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Learning Objectives</a></span></li><li><span><a href="#Create-Dask-Cluster" data-toc-modified-id="Create-Dask-Cluster-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Create Dask Cluster</a></span></li><li><span><a href="#Open-an-intake-esm-catalog-for-CESM1-LE-data-stored-on-Glade-and-Tape" data-toc-modified-id="Open-an-intake-esm-catalog-for-CESM1-LE-data-stored-on-Glade-and-Tape-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Open an intake-esm catalog for CESM1-LE data stored on Glade and Tape</a></span></li><li><span><a href="#Load-oxygen-Data-From-Control-Run-into-an-Xarray-Dataset-and-Compute-its-Annual-Mean" data-toc-modified-id="Load-oxygen-Data-From-Control-Run-into-an-Xarray-Dataset-and-Compute-its-Annual-Mean-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Load oxygen Data From Control Run into an Xarray Dataset and Compute its Annual Mean</a></span></li><li><span><a href="#Load-oxygen-Data-From-20C,-RCP85-Runs-into-an-Xarray-Dataset-and-Compute-its-Annual-Mean" data-toc-modified-id="Load-oxygen-Data-From-20C,-RCP85-Runs-into-an-Xarray-Dataset-and-Compute-its-Annual-Mean-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Load oxygen Data From 20C, RCP85 Runs into an Xarray Dataset and Compute its Annual Mean</a></span></li><li><span><a href="#Compute-Linear-Trend" data-toc-modified-id="Compute-Linear-Trend-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Compute Linear Trend</a></span></li><li><span><a href="#Plot-All-Trends---Total" data-toc-modified-id="Plot-All-Trends---Total-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Plot All Trends - Total</a></span></li><li><span><a href="#Plot-All-Trends---Internal" data-toc-modified-id="Plot-All-Trends---Internal-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Plot All Trends - Internal</a></span></li><li><span><a href="#Going-Further" data-toc-modified-id="Going-Further-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Going Further</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Finding forced trends in oceanic oxygen

# %% [markdown]
# ## Learning Objectives
#
#
# -

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from ncar_jobqueue import NCARCluster
from dask.distributed import Client
import esmlab
import xarray as xr
import numpy as np
import dask
import util

# %% [markdown]
# ## Create Dask Cluster

# %% [markdown]
# (👆don't forget to look at the dashboard!)

# %%
from ncar_jobqueue import NCARCluster
#cluster = NCARCluster()
cluster = NCARCluster(project='UCUC0006')
cluster.scale(36) #adapt(minimum_jobs=1, maximum_jobs=40)
cluster
# Out:
# VBox(children=(HTML(value='<h2>NCARCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp_t1kqc70.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp_t1kqc70.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpkqj4ujtc.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpkqj4ujtc.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpqz7q3d8y.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpqz7q3d8y.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpsbm_ovpx.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpsbm_ovpx.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpszj3yl_w.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpszj3yl_w.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp8mfyl99l.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp8mfyl99l.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp20nv7whe.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp20nv7whe.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpkbn6fojo.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpkbn6fojo.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp_5fdu22i.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp_5fdu22i.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpdo4s3cdq.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpdo4s3cdq.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp0zf5vogi.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp0zf5vogi.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmps1nbz5jc.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmps1nbz5jc.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmplu0wxcgj.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmplu0wxcgj.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpfgg8ltpv.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpfgg8ltpv.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp3ld0w1eg.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp3ld0w1eg.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmptq6tpsan.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmptq6tpsan.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpa0ndby9y.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpa0ndby9y.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpqsv5lhq_.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpqsv5lhq_.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpsf8k3o6r.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpsf8k3o6r.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpt06_qrt6.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpt06_qrt6.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmphxv28y5n.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmphxv28y5n.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpov7zyk10.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpov7zyk10.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp2dir5czw.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp2dir5czw.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpvax1wqc0.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpvax1wqc0.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpy1ly4shv.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
# ...
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp6k90kmzh.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpkbav6g3z.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpkbav6g3z.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpv53lo9kt.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpv53lo9kt.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpw4glgods.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpw4glgods.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp72ue1yql.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp72ue1yql.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp9ytg41wk.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp9ytg41wk.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp8uwzh_pv.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp8uwzh_pv.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp48lg42g5.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp48lg42g5.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpam5l9nk1.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpam5l9nk1.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client
# Out:
# <Client: 'tcp://10.12.205.11:38704' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Open an intake-esm catalog for CESM1-LE data stored on Glade and Tape

# %%
import intake
from intake_esm import config

# %%
#with config.set({'database-directory': '/glade/u/home/abanihi/.intake_esm/collections'}):
col = intake.open_esm_metadatastore(collection_name='CESM1-LE')

col.df.head()

# %%
keep_vars = ['O2', 'z_t', 'KMT', 'TAREA', 'TLONG',
             'TLAT', 'time', 'time_bound', 'member_id']
yr0, yr1 = 2006, 2055
time_slice = slice(f'{yr0:04d}', f'{yr1:04d}')
ctrl_time_slice = slice(f'{yr0-1448:04d}', f'{yr1-1448:04d}')

# %% [markdown]
# ## Load oxygen Data From Control Run into an Xarray Dataset and Compute its Annual Mean

# %%
# %%time
dsets = col.search(experiment=['CTRL'], variable=['O2'])\
        .to_xarray(decode_times=False, chunks={'time': 240})
_, dd = dsets.popitem()
ctrl = util.clean_ds(dd, keep_vars)
ctrl = util.sel_time(ctrl, ctrl_time_slice)
ctrl = esmlab.resample(ctrl, freq='ann')
print(ctrl)

# %% [markdown]
# ## Load oxygen Data From 20C, RCP85 Runs into an Xarray Dataset and Compute its Annual Mean

# %%
# %%time
dsets = col.search(experiment=['20C', 'RCP85'], variable=['O2'])\
        .to_xarray(decode_times=False, chunks={'time': 240})
print(dsets.keys())
ds_20c = dsets['ocn.20C.pop.h']
ds_rcp85 = dsets['ocn.RCP85.pop.h']
dd = xr.concat([ds_20c, ds_rcp85], dim='time')
ds = util.clean_ds(dd, keep_vars)
ds = util.sel_time(ds, time_slice)
ds = esmlab.resample(ds, freq='ann')
print(ds)

# %% [markdown]
# ## Compute Linear Trend
#
# Define helper functions for trend computation.

# %%
def linear_trend(da, dim='time'):
    da_chunk = da.chunk({dim: -1})
    trend = xr.apply_ufunc(calc_slope,
                           da_chunk,
                           vectorize=True,
                           input_core_dims=[[dim]],
                           output_core_dims=[[]],
                           output_dtypes=[np.float],
                           dask='parallelized')
    return trend


def calc_slope(y):
    """ufunc to be used by linear_trend"""
    x = np.arange(len(y))
    return np.polyfit(x, y, 1)[0]

# %% [markdown]
# Compute linear trends on the control integration.

# %%
# %%time
ctrl_trend = linear_trend(ctrl.O2.chunk({
    'nlat': 30,
    'nlon': 30,
    'time': -1
})).load()
ctrl_trend = ctrl_trend * len(ctrl.time)
ctrl_trend.attrs['units'] = f'mmol m$^{{-3}}$ ({len(ctrl.time)} yr)$^{{-1}}$'
ctrl_trend.plot()

# %% [markdown]
# Compute linear trends on the full ensemble.

# %%
# %%time
ds_trend = linear_trend(ds.O2.chunk({'nlat': 30, 'nlon': 30, 'time': -1}))\
                       .load()
ds_trend = ds_trend * len(ds.time)
ds_trend.attrs['units'] = f'mmol m$^{{-3}}$ ({len(ds.time)} yr)$^{{-1}}$'
ds_trend.isel(member_id=3).plot()

# %% [markdown]
# ## Visualize trends
#
# For visualization purposes, look for the ensemble members with the smallest and largest regional trends. In this case, we'll focus on the N. Pacific.
#
# First step: compute the mean trend over the N. Pacific.

# %%
npac_trend = ds_trend.where((10 < ds.TLAT) & (ds.TLAT < 65) & (120 < ds.TLONG)
                            & (ds.TLONG < 260))
npac_trend = esmlab.weighted_mean(npac_trend,
                                  dim=('nlat', 'nlon'),
                                  weights=ds.TAREA).load()

# %%
npac_trend

# %% [markdown]
# Next, pick out the ensemble members with the min and max trends.

# %%
member_id_pick = [
    npac_trend.where(npac_trend == npac_trend.max(),
                     drop=True).member_id.values.astype('int')[0],
    npac_trend.where(npac_trend == npac_trend.min(),
                     drop=True).member_id.values.astype('int')[0]
]

# %%
member_id_pick

# %% [markdown]
# Import plotting modules

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import cmocean
import cartopy.crs as ccrs
import cartopy

# %% [markdown]
# Make a dataset suitable for plotting. In this case, `pop_add_cyclic` reformats the data on the ocean grid to enable seamless plotting on a contour map.

# %%
dsp = util.pop_add_cyclic(
    xr.Dataset({
        'trend': ds_trend,
        'TLAT': ds.TLAT[0].compute(),
        'TLONG': ds.TLONG[0].compute()
    }))
dsp

# %% [markdown]
# Compute the `forced` (ensemble mean) and `internal` components. Call `compute` on these dataset to trigger loading into memory so that subsequent plotting operations proceed as rapidly as possible.

# %%
forced = dsp.trend.mean('member_id').compute()
internal = [(dsp.trend.sel(member_id=i) - forced).compute()
            for i in member_id_pick]

forced

# %% [markdown]
# Set up some basic plotting variables, i.e., contour levels, map projection.

# %%
levels = np.arange(-100, 45, 5)
norm = colors.DivergingNorm(vmin=levels[0], vmax=levels[-1], vcenter=0.)

extent = [120, 260, 10, 65]
prj = ccrs.Mercator(central_longitude=np.mean(extent[0:2]),
                    min_latitude=extent[2],
                    max_latitude=extent[3])

# %% [markdown]
# Define a helper function that makes a single map plot.

# %%
def one_plot(da, lines=True):
    # filled contours
    cf = ax.contourf(dsp.TLONG,
                     dsp.TLAT,
                     da,
                     levels=levels,
                     norm=norm,
                     cmap=cmocean.cm.curl_r,
                     extend='both',
                     transform=ccrs.PlateCarree())

    # contour lines
    cs = ax.contour(dsp.TLONG,
                    dsp.TLAT,
                    da,
                    colors='k',
                    levels=levels,
                    linewidths=0.5,
                    transform=ccrs.PlateCarree())

    if lines:
        # add contour labels
        lb = plt.clabel(cs, fontsize=6, inline=True, fmt='%r')

    # land
    land = ax.add_feature(
        cartopy.feature.NaturalEarthFeature('physical',
                                            'land',
                                            '110m',
                                            facecolor='lightgray'))

    ax.coastlines(linewidth=0.5)

    return cf

# %% [markdown]
# Make a plot showing the Total trend and it's internal and forced components for the ensemble members with the min and max N. Pacific trends.

# %%
fig = plt.figure(figsize=(12, 6))

axs = []

# plot total
ax = fig.add_subplot(2, 3, 1, projection=prj)
ax.set_extent(extent)
one_plot(dsp.trend.sel(member_id=member_id_pick[0]))
ax.text(235., 60, f'{member_id_pick[0]:03d}', transform=ccrs.PlateCarree())
ax.set_title('Total')
axs.append(ax)

ax = fig.add_subplot(2, 3, 4, projection=prj)
ax.set_extent(extent)
one_plot(dsp.trend.sel(member_id=member_id_pick[1]))
ax.text(235., 60, f'{member_id_pick[1]:03d}', transform=ccrs.PlateCarree())
axs.append(ax)

# plot internal variability
ax = fig.add_subplot(2, 3, 2, projection=prj)
ax.set_extent(extent)
one_plot(internal[0])
ax.text(235., 60, f'{member_id_pick[0]:03d}', transform=ccrs.PlateCarree())
ax.set_title('Internal')
axs.append(ax)

ax = fig.add_subplot(2, 3, 5, projection=prj)
ax.set_extent(extent)
one_plot(internal[1])
ax.text(235., 60, f'{member_id_pick[1]:03d}', transform=ccrs.PlateCarree())
axs.append(ax)

# plot forced
ax = fig.add_subplot(2, 3, 3, projection=prj)
ax.set_extent(extent)
one_plot(forced)
ax.set_title('Forced')
axs.append(ax)

ax = fig.add_subplot(2, 3, 6, projection=prj)
ax.set_extent(extent)
cf = one_plot(forced)
axs.append(ax)

# add colorbar
plt.subplots_adjust(hspace=0.02, wspace=0.02)

# colorbar and labels
cb = plt.colorbar(cf, shrink=0.5, orientation='horizontal', ax=axs, pad=0.075)
cb.ax.set_title(dsp.trend.units)
plt.savefig('trend-decomp-O2-200m-NPac.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Plot All Trends - Total
#
# Make a postage stamp plot showing all the trends. First compute each ensemble member to load into memory.

# %%
field = [
    dsp.trend.isel(member_id=i).compute() for i in range(0, len(ds.member_id))
]

# %%
fig = plt.figure(figsize=(10, 10))

axs = []

# plot total
for i in range(0, len(ds.member_id)):
    ax = fig.add_subplot(7, 5, i + 1, projection=prj)
    ax.set_extent(extent)
    cf = one_plot(field[i], lines=False)
    axs.append(ax)

plt.subplots_adjust(hspace=0.04, wspace=0.02)

# colorbar and labels
cb = plt.colorbar(cf, shrink=0.5, orientation='horizontal', ax=axs, pad=0.075)
cb.ax.set_title(dsp.trend.units)

plt.savefig('all-trends-O2-200m-NPac.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### Plot All Trends - Internal

# %%
fig = plt.figure(figsize=(10, 10))

axs = []

# plot total
for i in range(0, len(ds.member_id)):
    ax = fig.add_subplot(7, 5, i + 1, projection=prj)
    ax.set_extent(extent)
    cf = one_plot(field[i] - forced, lines=False)
    axs.append(ax)

plt.subplots_adjust(hspace=0.04, wspace=0.02)

# colorbar and labels
cb = plt.colorbar(cf, shrink=0.5, orientation='horizontal', ax=axs, pad=0.075)
cb.ax.set_title(dsp.trend.units)

plt.savefig('all-trends-internal-O2-200m-NPac.png',
            dpi=300,
            bbox_inches='tight')

# %% [markdown]
# ## Going Further

# %%
cluster.close()
# Out:
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpttw5_nd8.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpttw5_nd8.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpvbpkfog0.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpvbpkfog0.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpci7t29c4.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpci7t29c4.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpb8couypi.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpb8couypi.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpgmmacx75.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpgmmacx75.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp_7c5kjd6.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp_7c5kjd6.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpnb5o3ntw.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpnb5o3ntw.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpr1ea8kbg.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpr1ea8kbg.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp6krr5ves.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp6krr5ves.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpxysf09iu.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpxysf09iu.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpvduq0iep.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpvduq0iep.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp2m8warsa.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp2m8warsa.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmprc6muxk4.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmprc6muxk4.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpo3lko602.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpo3lko602.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpyuv_ixg7.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpyuv_ixg7.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp2xcidrt_.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp2xcidrt_.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp2ewuymq5.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp2ewuymq5.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpf89trhla.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpf89trhla.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpi02clcdp.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpi02clcdp.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpc2pongzu.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpc2pongzu.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpk5c2juvd.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpk5c2juvd.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpsavzb9e1.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpsavzb9e1.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmphu69230b.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmphu69230b.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp2xhwfh2z.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp2xhwfh2z.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpst5nicbv.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpst5nicbv.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmptk1npako.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmptk1npako.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpoadio818.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpoadio818.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmp43wrl_j_.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmp43wrl_j_.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpn8o6eybc.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpn8o6eybc.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpg66brmfu.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpg66brmfu.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# Task exception was never retrieved
# future: <Task finished coro=<_wrap_awaitable() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py:623> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpq467xacw.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/asyncio/tasks.py", line 630, in _wrap_awaitable
#     return (yield from awaitable.__await__())
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpq467xacw.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
#
#
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x2b9a339a5110>>, <Task finished coro=<AdaptiveCore.adapt() done, defined at /glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py:170> exception=RuntimeError('Command exited with non-zero exit code.\nExit code: 1\nCommand:\nsbatch /glade/scratch/zephyrs/tmp/tmpj9wm622_.sh\nstdout:\n\nstderr:\nsbatch: error: You must specify an account (--account)\nContact cislhelp@ucar.edu for assistance\nsbatch: error: Batch job submission failed: Access/permission denied\n\n')>)
# Traceback (most recent call last):
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/tornado/ioloop.py", line 767, in _discard_future_result
#     future.result()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive_core.py", line 183, in adapt
#     recommendations = await self.recommendations(target)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/adaptive.py", line 151, in recommendations
#     await self.cluster
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 366, in _
#     await self._correct_state()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 335, in _correct_state_internal
#     await w  # for tornado gen.coroutine support
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/distributed/deploy/spec.py", line 50, in _
#     await self.start()
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 310, in start
#     out = await self._submit_job(fn)
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 293, in _submit_job
#     return self._call(shlex.split(self.submit_command) + [script_filename])
#   File "/glade/work/zephyrs/miniconda3/envs/krill/lib/python3.7/site-packages/dask_jobqueue/core.py", line 393, in _call
#     "stderr:\n{}\n".format(proc.returncode, cmd_str, out, err)
# RuntimeError: Command exited with non-zero exit code.
# Exit code: 1
# Command:
# sbatch /glade/scratch/zephyrs/tmp/tmpj9wm622_.sh
# stdout:
#
# stderr:
# sbatch: error: You must specify an account (--account)
# Contact cislhelp@ucar.edu for assistance
# sbatch: error: Batch job submission failed: Access/permission denied
